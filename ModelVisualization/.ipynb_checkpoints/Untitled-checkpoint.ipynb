# %%
from nngmodel import get_testing_model
from keras import applications
from keras import backend as K
import numpy as np
from scipy.misc import imsave
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import time

img_width = 128
img_height = 128

# Load model
model_path = "model.h5"

model = get_testing_model()
model.load_weights(model_path)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, None, None, 3 0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_1 (Conv2D)                (None, None, None, 6 1792        lambda_2[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, None, 6 0           conv1_1[0][0]
# __________________________________________________________________________________________________
# conv1_2 (Conv2D)                (None, None, None, 6 36928       activation_81[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, None, None, 6 0           conv1_2[0][0]
# __________________________________________________________________________________________________
# pool1_1 (MaxPooling2D)          (None, None, None, 6 0           activation_82[0][0]
# __________________________________________________________________________________________________
# conv2_1 (Conv2D)                (None, None, None, 1 73856       pool1_1[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, None, 1 0           conv2_1[0][0]
# __________________________________________________________________________________________________
# conv2_2 (Conv2D)                (None, None, None, 1 147584      activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, None, 1 0           conv2_2[0][0]
# __________________________________________________________________________________________________
# pool2_1 (MaxPooling2D)          (None, None, None, 1 0           activation_84[0][0]
# __________________________________________________________________________________________________
# conv3_1 (Conv2D)                (None, None, None, 2 295168      pool2_1[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, None, None, 2 0           conv3_1[0][0]
# __________________________________________________________________________________________________
# conv3_2 (Conv2D)                (None, None, None, 2 590080      activation_85[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, None, 2 0           conv3_2[0][0]
# __________________________________________________________________________________________________
# conv3_3 (Conv2D)                (None, None, None, 2 590080      activation_86[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, None, 2 0           conv3_3[0][0]
# __________________________________________________________________________________________________
# conv3_4 (Conv2D)                (None, None, None, 2 590080      activation_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, None, None, 2 0           conv3_4[0][0]
# __________________________________________________________________________________________________
# pool3_1 (MaxPooling2D)          (None, None, None, 2 0           activation_88[0][0]
# __________________________________________________________________________________________________
# conv4_1 (Conv2D)                (None, None, None, 5 1180160     pool3_1[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, None, 5 0           conv4_1[0][0]
# __________________________________________________________________________________________________
# conv4_2 (Conv2D)                (None, None, None, 5 2359808     activation_89[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, None, None, 5 0           conv4_2[0][0]
# __________________________________________________________________________________________________
# conv4_3_CPM (Conv2D)            (None, None, None, 2 1179904     activation_90[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, None, None, 2 0           conv4_3_CPM[0][0]
# __________________________________________________________________________________________________
# conv4_4_CPM (Conv2D)            (None, None, None, 1 295040      activation_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, None, None, 1 0           conv4_4_CPM[0][0]
# __________________________________________________________________________________________________
# Mconv1_stage1_L1 (Conv2D)       (None, None, None, 1 147584      activation_92[0][0]
# __________________________________________________________________________________________________
# Mconv1_stage1_L2 (Conv2D)       (None, None, None, 1 147584      activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, None, None, 1 0           Mconv1_stage1_L1[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, None, None, 1 0           Mconv1_stage1_L2[0][0]
# __________________________________________________________________________________________________
# Mconv2_stage1_L1 (Conv2D)       (None, None, None, 1 147584      activation_93[0][0]
# __________________________________________________________________________________________________
# Mconv2_stage1_L2 (Conv2D)       (None, None, None, 1 147584      activation_97[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, None, None, 1 0           Mconv2_stage1_L1[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, None, None, 1 0           Mconv2_stage1_L2[0][0]
# __________________________________________________________________________________________________
# Mconv3_stage1_L1 (Conv2D)       (None, None, None, 1 147584      activation_94[0][0]
# __________________________________________________________________________________________________
# Mconv3_stage1_L2 (Conv2D)       (None, None, None, 1 147584      activation_98[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, None, None, 1 0           Mconv3_stage1_L1[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, None, None, 1 0           Mconv3_stage1_L2[0][0]
# __________________________________________________________________________________________________
# Mconv4_stage1_L1 (Conv2D)       (None, None, None, 5 66048       activation_95[0][0]
# __________________________________________________________________________________________________
# Mconv4_stage1_L2 (Conv2D)       (None, None, None, 5 66048       activation_99[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, None, None, 5 0           Mconv4_stage1_L1[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, None, None, 5 0           Mconv4_stage1_L2[0][0]
# __________________________________________________________________________________________________
# Mconv5_stage1_L1 (Conv2D)       (None, None, None, 3 19494       activation_96[0][0]
# __________________________________________________________________________________________________
# Mconv5_stage1_L2 (Conv2D)       (None, None, None, 1 9747        activation_100[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, None, None, 1 0           Mconv5_stage1_L1[0][0]
#                                                                  Mconv5_stage1_L2[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# Mconv1_stage2_L1 (Conv2D)       (None, None, None, 1 1160448     concatenate_6[0][0]
# __________________________________________________________________________________________________
# Mconv1_stage2_L2 (Conv2D)       (None, None, None, 1 1160448     concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, None, None, 1 0           Mconv1_stage2_L1[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, None, None, 1 0           Mconv1_stage2_L2[0][0]
# __________________________________________________________________________________________________
# Mconv2_stage2_L1 (Conv2D)       (None, None, None, 1 802944      activation_101[0][0]
# __________________________________________________________________________________________________
# Mconv2_stage2_L2 (Conv2D)       (None, None, None, 1 802944      activation_107[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, None, None, 1 0           Mconv2_stage2_L1[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, None, None, 1 0           Mconv2_stage2_L2[0][0]
# __________________________________________________________________________________________________
# Mconv3_stage2_L1 (Conv2D)       (None, None, None, 1 802944      activation_102[0][0]
# __________________________________________________________________________________________________
# Mconv3_stage2_L2 (Conv2D)       (None, None, None, 1 802944      activation_108[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, None, None, 1 0           Mconv3_stage2_L1[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, None, None, 1 0           Mconv3_stage2_L2[0][0]
# __________________________________________________________________________________________________
# Mconv4_stage2_L1 (Conv2D)       (None, None, None, 1 802944      activation_103[0][0]
# __________________________________________________________________________________________________
# Mconv4_stage2_L2 (Conv2D)       (None, None, None, 1 802944      activation_109[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, None, None, 1 0           Mconv4_stage2_L1[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, None, None, 1 0           Mconv4_stage2_L2[0][0]
# __________________________________________________________________________________________________
# Mconv5_stage2_L1 (Conv2D)       (None, None, None, 1 802944      activation_104[0][0]
# __________________________________________________________________________________________________
# Mconv5_stage2_L2 (Conv2D)       (None, None, None, 1 802944      activation_110[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, None, None, 1 0           Mconv5_stage2_L1[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, None, None, 1 0           Mconv5_stage2_L2[0][0]
# __________________________________________________________________________________________________
# Mconv6_stage2_L1 (Conv2D)       (None, None, None, 1 16512       activation_105[0][0]
# __________________________________________________________________________________________________
# Mconv6_stage2_L2 (Conv2D)       (None, None, None, 1 16512       activation_111[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, None, None, 1 0           Mconv6_stage2_L1[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, None, None, 1 0           Mconv6_stage2_L2[0][0]
# __________________________________________________________________________________________________
# Mconv7_stage2_L1 (Conv2D)       (None, None, None, 3 4902        activation_106[0][0]
# __________________________________________________________________________________________________
# Mconv7_stage2_L2 (Conv2D)       (None, None, None, 1 2451        activation_112[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, None, None, 1 0           Mconv7_stage2_L1[0][0]
#                                                                  Mconv7_stage2_L2[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# Mconv1_stage3_L1 (Conv2D)       (None, None, None, 1 1160448     concatenate_7[0][0]
# __________________________________________________________________________________________________
# Mconv1_stage3_L2 (Conv2D)       (None, None, None, 1 1160448     concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, None, None, 1 0           Mconv1_stage3_L1[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, None, None, 1 0           Mconv1_stage3_L2[0][0]
# __________________________________________________________________________________________________
# Mconv2_stage3_L1 (Conv2D)       (None, None, None, 1 802944      activation_113[0][0]
# __________________________________________________________________________________________________
# Mconv2_stage3_L2 (Conv2D)       (None, None, None, 1 802944      activation_119[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, None, None, 1 0           Mconv2_stage3_L1[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, None, None, 1 0           Mconv2_stage3_L2[0][0]
# __________________________________________________________________________________________________
# Mconv3_stage3_L1 (Conv2D)       (None, None, None, 1 802944      activation_114[0][0]
# __________________________________________________________________________________________________
# Mconv3_stage3_L2 (Conv2D)       (None, None, None, 1 802944      activation_120[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, None, None, 1 0           Mconv3_stage3_L1[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, None, None, 1 0           Mconv3_stage3_L2[0][0]
# __________________________________________________________________________________________________
# Mconv4_stage3_L1 (Conv2D)       (None, None, None, 1 802944      activation_115[0][0]
# __________________________________________________________________________________________________
# Mconv4_stage3_L2 (Conv2D)       (None, None, None, 1 802944      activation_121[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, None, None, 1 0           Mconv4_stage3_L1[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, None, None, 1 0           Mconv4_stage3_L2[0][0]
# __________________________________________________________________________________________________
# Mconv5_stage3_L1 (Conv2D)       (None, None, None, 1 802944      activation_116[0][0]
# __________________________________________________________________________________________________
# Mconv5_stage3_L2 (Conv2D)       (None, None, None, 1 802944      activation_122[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, None, None, 1 0           Mconv5_stage3_L1[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, None, None, 1 0           Mconv5_stage3_L2[0][0]
# __________________________________________________________________________________________________
# Mconv6_stage3_L1 (Conv2D)       (None, None, None, 1 16512       activation_117[0][0]
# __________________________________________________________________________________________________
# Mconv6_stage3_L2 (Conv2D)       (None, None, None, 1 16512       activation_123[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, None, None, 1 0           Mconv6_stage3_L1[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, None, None, 1 0           Mconv6_stage3_L2[0][0]
# __________________________________________________________________________________________________
# Mconv7_stage3_L1 (Conv2D)       (None, None, None, 3 4902        activation_118[0][0]
# __________________________________________________________________________________________________
# Mconv7_stage3_L2 (Conv2D)       (None, None, None, 1 2451        activation_124[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, None, None, 1 0           Mconv7_stage3_L1[0][0]
#                                                                  Mconv7_stage3_L2[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# Mconv1_stage4_L1 (Conv2D)       (None, None, None, 1 1160448     concatenate_8[0][0]
# __________________________________________________________________________________________________
# Mconv1_stage4_L2 (Conv2D)       (None, None, None, 1 1160448     concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, None, None, 1 0           Mconv1_stage4_L1[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, None, None, 1 0           Mconv1_stage4_L2[0][0]
# __________________________________________________________________________________________________
# Mconv2_stage4_L1 (Conv2D)       (None, None, None, 1 802944      activation_125[0][0]
# __________________________________________________________________________________________________
# Mconv2_stage4_L2 (Conv2D)       (None, None, None, 1 802944      activation_131[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, None, None, 1 0           Mconv2_stage4_L1[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, None, None, 1 0           Mconv2_stage4_L2[0][0]
# __________________________________________________________________________________________________
# Mconv3_stage4_L1 (Conv2D)       (None, None, None, 1 802944      activation_126[0][0]
# __________________________________________________________________________________________________
# Mconv3_stage4_L2 (Conv2D)       (None, None, None, 1 802944      activation_132[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, None, None, 1 0           Mconv3_stage4_L1[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, None, None, 1 0           Mconv3_stage4_L2[0][0]
# __________________________________________________________________________________________________
# Mconv4_stage4_L1 (Conv2D)       (None, None, None, 1 802944      activation_127[0][0]
# __________________________________________________________________________________________________
# Mconv4_stage4_L2 (Conv2D)       (None, None, None, 1 802944      activation_133[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, None, None, 1 0           Mconv4_stage4_L1[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, None, None, 1 0           Mconv4_stage4_L2[0][0]
# __________________________________________________________________________________________________
# Mconv5_stage4_L1 (Conv2D)       (None, None, None, 1 802944      activation_128[0][0]
# __________________________________________________________________________________________________
# Mconv5_stage4_L2 (Conv2D)       (None, None, None, 1 802944      activation_134[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, None, None, 1 0           Mconv5_stage4_L1[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, None, None, 1 0           Mconv5_stage4_L2[0][0]
# __________________________________________________________________________________________________
# Mconv6_stage4_L1 (Conv2D)       (None, None, None, 1 16512       activation_129[0][0]
# __________________________________________________________________________________________________
# Mconv6_stage4_L2 (Conv2D)       (None, None, None, 1 16512       activation_135[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, None, None, 1 0           Mconv6_stage4_L1[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, None, None, 1 0           Mconv6_stage4_L2[0][0]
# __________________________________________________________________________________________________
# Mconv7_stage4_L1 (Conv2D)       (None, None, None, 3 4902        activation_130[0][0]
# __________________________________________________________________________________________________
# Mconv7_stage4_L2 (Conv2D)       (None, None, None, 1 2451        activation_136[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, None, None, 1 0           Mconv7_stage4_L1[0][0]
#                                                                  Mconv7_stage4_L2[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# Mconv1_stage5_L1 (Conv2D)       (None, None, None, 1 1160448     concatenate_9[0][0]
# __________________________________________________________________________________________________
# Mconv1_stage5_L2 (Conv2D)       (None, None, None, 1 1160448     concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, None, None, 1 0           Mconv1_stage5_L1[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, None, None, 1 0           Mconv1_stage5_L2[0][0]
# __________________________________________________________________________________________________
# Mconv2_stage5_L1 (Conv2D)       (None, None, None, 1 802944      activation_137[0][0]
# __________________________________________________________________________________________________
# Mconv2_stage5_L2 (Conv2D)       (None, None, None, 1 802944      activation_143[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, None, None, 1 0           Mconv2_stage5_L1[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, None, None, 1 0           Mconv2_stage5_L2[0][0]
# __________________________________________________________________________________________________
# Mconv3_stage5_L1 (Conv2D)       (None, None, None, 1 802944      activation_138[0][0]
# __________________________________________________________________________________________________
# Mconv3_stage5_L2 (Conv2D)       (None, None, None, 1 802944      activation_144[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, None, None, 1 0           Mconv3_stage5_L1[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, None, None, 1 0           Mconv3_stage5_L2[0][0]
# __________________________________________________________________________________________________
# Mconv4_stage5_L1 (Conv2D)       (None, None, None, 1 802944      activation_139[0][0]
# __________________________________________________________________________________________________
# Mconv4_stage5_L2 (Conv2D)       (None, None, None, 1 802944      activation_145[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, None, None, 1 0           Mconv4_stage5_L1[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, None, None, 1 0           Mconv4_stage5_L2[0][0]
# __________________________________________________________________________________________________
# Mconv5_stage5_L1 (Conv2D)       (None, None, None, 1 802944      activation_140[0][0]
# __________________________________________________________________________________________________
# Mconv5_stage5_L2 (Conv2D)       (None, None, None, 1 802944      activation_146[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, None, None, 1 0           Mconv5_stage5_L1[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, None, None, 1 0           Mconv5_stage5_L2[0][0]
# __________________________________________________________________________________________________
# Mconv6_stage5_L1 (Conv2D)       (None, None, None, 1 16512       activation_141[0][0]
# __________________________________________________________________________________________________
# Mconv6_stage5_L2 (Conv2D)       (None, None, None, 1 16512       activation_147[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, None, None, 1 0           Mconv6_stage5_L1[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, None, None, 1 0           Mconv6_stage5_L2[0][0]
# __________________________________________________________________________________________________
# Mconv7_stage5_L1 (Conv2D)       (None, None, None, 3 4902        activation_142[0][0]
# __________________________________________________________________________________________________
# Mconv7_stage5_L2 (Conv2D)       (None, None, None, 1 2451        activation_148[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, None, None, 1 0           Mconv7_stage5_L1[0][0]
#                                                                  Mconv7_stage5_L2[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# Mconv1_stage6_L1 (Conv2D)       (None, None, None, 1 1160448     concatenate_10[0][0]
# __________________________________________________________________________________________________
# Mconv1_stage6_L2 (Conv2D)       (None, None, None, 1 1160448     concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, None, None, 1 0           Mconv1_stage6_L1[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, None, None, 1 0           Mconv1_stage6_L2[0][0]
# __________________________________________________________________________________________________
# Mconv2_stage6_L1 (Conv2D)       (None, None, None, 1 802944      activation_149[0][0]
# __________________________________________________________________________________________________
# Mconv2_stage6_L2 (Conv2D)       (None, None, None, 1 802944      activation_155[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, None, None, 1 0           Mconv2_stage6_L1[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, None, None, 1 0           Mconv2_stage6_L2[0][0]
# __________________________________________________________________________________________________
# Mconv3_stage6_L1 (Conv2D)       (None, None, None, 1 802944      activation_150[0][0]
# __________________________________________________________________________________________________
# Mconv3_stage6_L2 (Conv2D)       (None, None, None, 1 802944      activation_156[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, None, None, 1 0           Mconv3_stage6_L1[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, None, None, 1 0           Mconv3_stage6_L2[0][0]
# __________________________________________________________________________________________________
# Mconv4_stage6_L1 (Conv2D)       (None, None, None, 1 802944      activation_151[0][0]
# __________________________________________________________________________________________________
# Mconv4_stage6_L2 (Conv2D)       (None, None, None, 1 802944      activation_157[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, None, None, 1 0           Mconv4_stage6_L1[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, None, None, 1 0           Mconv4_stage6_L2[0][0]
# __________________________________________________________________________________________________
# Mconv5_stage6_L1 (Conv2D)       (None, None, None, 1 802944      activation_152[0][0]
# __________________________________________________________________________________________________
# Mconv5_stage6_L2 (Conv2D)       (None, None, None, 1 802944      activation_158[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, None, None, 1 0           Mconv5_stage6_L1[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, None, None, 1 0           Mconv5_stage6_L2[0][0]
# __________________________________________________________________________________________________
# Mconv6_stage6_L1 (Conv2D)       (None, None, None, 1 16512       activation_153[0][0]
# __________________________________________________________________________________________________
# Mconv6_stage6_L2 (Conv2D)       (None, None, None, 1 16512       activation_159[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, None, None, 1 0           Mconv6_stage6_L1[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, None, None, 1 0           Mconv6_stage6_L2[0][0]
# __________________________________________________________________________________________________
# Mconv7_stage6_L1 (Conv2D)       (None, None, None, 3 4902        activation_154[0][0]
# __________________________________________________________________________________________________
# Mconv7_stage6_L2 (Conv2D)       (None, None, None, 1 2451        activation_160[0][0]
# ==================================================================================================
# Total params: 52,311,446
# Trainable params: 52,311,446
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# build a loss function that maximizes the activation of the nth filter of the layer considered
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + K.epsilon())
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    if K.image_data_format() == 'channels_first':
        x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
def normalize(x):
    # utility function to normalize a tensor by its L2 norm
    return x / (K.sqrt(K.mean(K.square(x))) + K.epsilon())

# %%
vgg_layers = {'conv1_1', 'conv1_2', 'conv2_1', 'conv2_2', 'conv3_1', 'conv3_2', 'conv3_3', 'conv3_4', 'conv4_1', 'conv4_2', 'conv4_3_CPM', 'conv4_4_CPM'}

# %%
vgg_layers = {'conv1_1'}
# this is the placeholder for the input images
input_img = model.input

for layer_name in vgg_layers:
    kept_filters = []
    kernel_size = model.get_layer(layer_name).output_shape[3]
    for filter_index in range(kernel_size):
        print('Processing filter %d' % filter_index)
        start_time = time.time()

        # we build a loss function that maximizes the activation
        # of the nth filter of the layer considered
        layer_output = model.get_layer(layer_name).output
        if K.image_data_format() == 'channels_first':
            loss = K.mean(layer_output[:, filter_index, :, :])
        else:
            loss = K.mean(layer_output[:, :, :, filter_index])

        # we compute the gradient of the input picture wrt this loss
        grads = K.gradients(loss, input_img)[0]

        # normalization trick: we normalize the gradient
        grads = normalize(grads)

        # this function returns the loss and grads given the input picture
        iterate = K.function([input_img], [loss, grads])

        # step size for gradient ascent
        step = 1.

        # we start from a gray image with some random noise
        if K.image_data_format() == 'channels_first':
            input_img_data = np.random.random((1, 3, img_width, img_height))
        else:
            input_img_data = np.random.random((1, img_width, img_height, 3))
        input_img_data = (input_img_data - 0.5) * 20 + 128

        # we run gradient ascent for 20 steps
        for i in range(20):
            loss_value, grads_value = iterate([input_img_data])
            input_img_data += grads_value * step

            print('Current loss value:', loss_value)

        # decode the resulting input image
        img = deprocess_image(input_img_data[0])
        kept_filters.append((img, loss_value))
        end_time = time.time()
        print('Filter %d processed in %ds' % (filter_index, end_time - start_time))

    # we will stich the best 64 filters on a 8 x 8 grid.
    n = kernel_size
    n = int(np.ceil(np.sqrt(n)))
    
    # the filters that have the highest loss are assumed to be better-looking.
    # we will only keep the top 64 filters.
    kept_filters.sort(key=lambda x: x[1], reverse=True)
    kept_filters = kept_filters[:n * n]

    # build a black picture with enough space for
    # our 8 x 8 filters of size 128 x 128, with a 5px margin in between
    margin = 5
    width = n * img_width + (n - 1) * margin
    height = n * img_height + (n - 1) * margin
    stitched_filters = np.zeros((width, height, 3))

    # fill the picture with our saved filters
    for index in range(kernel_size):
        img, loss = kept_filters[index]
        i = index // n
        j = index % n
        stitched_filters[(img_width + margin) * i: (img_width + margin) * i + img_width,
                        (img_height + margin) * j: (img_height + margin) * j + img_height, :] = img

    # save the result to disk
    imsave('%s_stitched_filters_%d.png' % (layer_name,kernel_size), stitched_filters)
# Out:
# Processing filter 0
# Current loss value: 0.104355
# Current loss value: 0.105277
# Current loss value: 0.106199
